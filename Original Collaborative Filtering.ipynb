# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
df = pd.read_excel(r'C:\Users\LTE\Desktop\Yeshiva DAV\Fall_2022\Recommender Systems\Collaborative Filtering.xlsx') 
df.head(10)
# Out:
#      Brand  Olivia  ZJY  LHR  ZHC  ZYC  Jason  Tianen  BrandAvg
# 0   Huawei     NaN  4.0  5.0  4.0  3.0    3.0   5.000  4.000000
# 1   Xiaomi     5.0  3.0  3.0  3.0  4.0    4.0   4.000  3.714286
# 2     Vivo     NaN  NaN  NaN  3.5  NaN    NaN     NaN  3.500000
# 3    Apple     4.5  4.0  4.0  4.5  3.0    NaN   4.500  4.083333
# 4  Samsung     3.0  4.0  NaN  3.5  3.0    NaN   4.000  3.500000
# 5     Sony     NaN  NaN  NaN  2.5  NaN    NaN     NaN  2.500000
# 6   Tianen     5.0  4.0  NaN  4.5  4.0    NaN   4.375  4.375000

# %%
cv = CountVectorizer()
count_matrix = cv.fit_transform(df["BrandAvg"])
cosine_sim = cosine_similarity(count_matrix)
def get_title_from_index(index):
    return df[df.index == index]["Brand"].values[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-f26ca1f5f55f> in <module>
#       1 cv = CountVectorizer()
# ----> 2 count_matrix = cv.fit_transform(df["BrandAvg"])
#       3 cosine_sim = cosine_similarity(count_matrix)
#       4 def get_title_from_index(index):
#       5     return df[df.index == index]["Brand"].values[0]
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1201         max_features = self.max_features
#    1202
# -> 1203         vocabulary, X = self._count_vocab(raw_documents,
#    1204                                           self.fixed_vocabulary_)
#    1205
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1113         for doc in raw_documents:
#    1114             feature_counter = {}
# ...
